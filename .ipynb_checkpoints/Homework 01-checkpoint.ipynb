# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '3.0.6'

# %%
df = pd.read_csv("https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv")

# %%
df
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# ...

# %%
# 1. Get the total number of rows (fastest & most common)
total_rows = len(df)

total_rows
# Out:
# 10000

# %%
df.fuel_type.nunique()
# Out:
# 3

# %%
df.fuel_efficiency_mpg.max()
# Out:
# np.float64(41.2)

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df.horsepower.median()
# Out:
# np.float64(254.0)

# %%
df.horsepower.mode()
# Out:
# 0    252.0
# Name: horsepower, dtype: float64

# %%
# Find the most frequent value (the [0] grabs the top value in case of a tie)
most_frequent_value = df['horsepower'].mode()[0]

# Replace the missing (NaN) values in that column
df['horsepower'] = df['horsepower'].fillna(most_frequent_value)

df['horsepower']
# Out:
# 0       243.0
# 1       272.0
# 2       267.0
# 3       258.0
# 4       304.0
#         ...
# 9995    271.0
# 9996    244.0
# 9997    267.0
# 9998    270.0
# 9999    295.0
# Name: horsepower, Length: 10000, dtype: float64

# %%
df.horsepower.isnull().sum()
# Out:
# np.int64(0)

# %%
df.horsepower.median()
# Out:
# np.float64(252.0)

# %%
asia_cars = df[df['origin'] == 'Asia']

# %%
selected_columns = asia_cars[['vehicle_weight', 'model_year']]

# %%
first_7 = selected_columns.head(7)

# %%
X = first_7.values

X
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %%
XTX = X.T.dot(X) 
XTX
# Out:
# array([[131950500,  60750580],
#        [ 60750580,  28041424]])

# %%
XTX_inv = np.linalg.inv(XTX)

XTX_inv
# Out:
# array([[ 2.96830537e-06, -6.43071025e-06],
#        [-6.43071025e-06,  1.39675281e-05]])

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
w = XTX_inv.dot(X.T).dot(y)

# %%
final_sum = w.sum()
print("The sum of all elements is:", final_sum)
# Out:
# The sum of all elements is: 0.36919696904925486
